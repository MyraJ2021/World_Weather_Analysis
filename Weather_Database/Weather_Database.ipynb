# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import weather_api_key

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# 4. Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

        # Print the city count to see.
len(cities)
# Out:
# 788

# %%
#Import the requests library.
import requests

# %%
# 5. Perform an API call with the OpenWeatherMap.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Test url.
test = requests.get(url)
test
# Out:
# <Response [400]>

# %%
# Import the time library and the datetime module from the datetime library.
import time
from datetime import datetime

# %%
# 6. Retrieve the following information from the API call: latitude and longitude, maximum temperature,
# percent humidity, percent cloudiness, wind speed, weather description (e.g, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | broome
# Processing Record 2 of Set 1 | kankon
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | carauari
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | shubarkuduk
# Processing Record 8 of Set 1 | tessalit
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | nikolayevsk-na-amure
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | asti
# Processing Record 16 of Set 1 | tambovka
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | imeni poliny osipenko
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | half moon bay
# Processing Record 21 of Set 1 | socorro
# Processing Record 22 of Set 1 | lukovetskiy
# Processing Record 23 of Set 1 | ponta do sol
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | katiola
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | lata
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | mount isa
# Processing Record 35 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 36 of Set 1 | aswan
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | mormugao
# Processing Record 39 of Set 1 | fort nelson
# Processing Record 40 of Set 1 | salalah
# Processing Record 41 of Set 1 | gizo
# Processing Record 42 of Set 1 | tortoli
# Processing Record 43 of Set 1 | mattru
# Processing Record 44 of Set 1 | hailar
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | kalevala
# Processing Record 47 of Set 1 | kruisfontein
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | khandyga
# Processing Record 2 of Set 2 | norman wells
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | canutama
# Processing Record 5 of Set 2 | san policarpo
# Processing Record 6 of Set 2 | torbay
# Processing Record 7 of Set 2 | collie
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | lebu
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | andros town
# Processing Record 13 of Set 2 | najran
# Processing Record 14 of Set 2 | faanui
# Processing Record 15 of Set 2 | shangzhi
# Processing Record 16 of Set 2 | ibotirama
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | talnakh
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | codrington
# Processing Record 21 of Set 2 | kalengwa
# Processing Record 22 of Set 2 | kieta
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | butaritari
# Processing Record 25 of Set 2 | luderitz
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | mareeba
# Processing Record 29 of Set 2 | shingu
# Processing Record 30 of Set 2 | alofi
# Processing Record 31 of Set 2 | smoky lake
# Processing Record 32 of Set 2 | naze
# Processing Record 33 of Set 2 | tura
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | saldanha
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | seymchan
# Processing Record 38 of Set 2 | saint anthony
# Processing Record 39 of Set 2 | imbituba
# Processing Record 40 of Set 2 | saint-esteve
# Processing Record 41 of Set 2 | vao
# Processing Record 42 of Set 2 | newport
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | poum
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | havre-saint-pierre
# Processing Record 47 of Set 2 | pevek
# Processing Record 48 of Set 2 | honningsvag
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | londoko
# Processing Record 1 of Set 3 | begusarai
# Processing Record 2 of Set 3 | the valley
# Processing Record 3 of Set 3 | mancio lima
# Processing Record 4 of Set 3 | guangyuan
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | manthani
# Processing Record 7 of Set 3 | adelanto
# Processing Record 8 of Set 3 | saint-augustin
# Processing Record 9 of Set 3 | aklavik
# Processing Record 10 of Set 3 | ancud
# Processing Record 11 of Set 3 | mayo
# Processing Record 12 of Set 3 | lepe
# Processing Record 13 of Set 3 | lac-megantic
# Processing Record 14 of Set 3 | vila franca do campo
# Processing Record 15 of Set 3 | guaratinga
# Processing Record 16 of Set 3 | bilma
# Processing Record 17 of Set 3 | laerdalsoyri
# Processing Record 18 of Set 3 | calamar
# Processing Record 19 of Set 3 | avarua
# Processing Record 20 of Set 3 | lahaina
# Processing Record 21 of Set 3 | vaini
# Processing Record 22 of Set 3 | bambanglipuro
# Processing Record 23 of Set 3 | abalak
# Processing Record 24 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 3 | garowe
# Processing Record 27 of Set 3 | barrow
# Processing Record 28 of Set 3 | ugoofaaru
# Processing Record 29 of Set 3 | bundaberg
# Processing Record 30 of Set 3 | maralal
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | cabinda
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | nelson bay
# Processing Record 35 of Set 3 | caravelas
# Processing Record 36 of Set 3 | naliya
# Processing Record 37 of Set 3 | longyearbyen
# Processing Record 38 of Set 3 | pinayagan
# City not found. Skipping...
# Processing Record 39 of Set 3 | namatanai
# Processing Record 40 of Set 3 | mangrol
# Processing Record 41 of Set 3 | port hardy
# Processing Record 42 of Set 3 | huazhou
# Processing Record 43 of Set 3 | merauke
# Processing Record 44 of Set 3 | kathmandu
# Processing Record 45 of Set 3 | panguna
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | sitka
# Processing Record 48 of Set 3 | port-gentil
# Processing Record 49 of Set 3 | ketchikan
# Processing Record 50 of Set 3 | aksarka
# Processing Record 1 of Set 4 | oktyabrskiy
# Processing Record 2 of Set 4 | chara
# Processing Record 3 of Set 4 | mogadishu
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | bengkulu
# Processing Record 6 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 7 of Set 4 | hobart
# Processing Record 8 of Set 4 | ahipara
# Processing Record 9 of Set 4 | isla vista
# Processing Record 10 of Set 4 | daxian
# City not found. Skipping...
# Processing Record 11 of Set 4 | port blair
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | nemuro
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 4 | saint george
# Processing Record 17 of Set 4 | barranca
# Processing Record 18 of Set 4 | mahebourg
# Processing Record 19 of Set 4 | diego de almagro
# Processing Record 20 of Set 4 | zaria
# Processing Record 21 of Set 4 | majene
# Processing Record 22 of Set 4 | dunedin
# Processing Record 23 of Set 4 | provideniya
# Processing Record 24 of Set 4 | uray
# Processing Record 25 of Set 4 | port alfred
# Processing Record 26 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 4 | mecca
# Processing Record 28 of Set 4 | maraba
# Processing Record 29 of Set 4 | aksu
# Processing Record 30 of Set 4 | eyl
# Processing Record 31 of Set 4 | ihosy
# Processing Record 32 of Set 4 | goderich
# Processing Record 33 of Set 4 | saint-pierre
# Processing Record 34 of Set 4 | turukhansk
# Processing Record 35 of Set 4 | cabo san lucas
# Processing Record 36 of Set 4 | gamba
# Processing Record 37 of Set 4 | chaa-khol
# City not found. Skipping...
# Processing Record 38 of Set 4 | acapulco
# Processing Record 39 of Set 4 | zunyi
# Processing Record 40 of Set 4 | burica
# City not found. Skipping...
# Processing Record 41 of Set 4 | hofn
# Processing Record 42 of Set 4 | vostok
# Processing Record 43 of Set 4 | shikhany
# Processing Record 44 of Set 4 | ostersund
# Processing Record 45 of Set 4 | lorengau
# Processing Record 46 of Set 4 | kainantu
# Processing Record 47 of Set 4 | saint-georges
# Processing Record 48 of Set 4 | east london
# Processing Record 49 of Set 4 | umm lajj
# Processing Record 50 of Set 4 | kupang
# Processing Record 1 of Set 5 | hami
# Processing Record 2 of Set 5 | union
# Processing Record 3 of Set 5 | kloulklubed
# Processing Record 4 of Set 5 | mugur-aksy
# Processing Record 5 of Set 5 | valandovo
# Processing Record 6 of Set 5 | chunskiy
# Processing Record 7 of Set 5 | atar
# Processing Record 8 of Set 5 | richards bay
# Processing Record 9 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 10 of Set 5 | yerbogachen
# Processing Record 11 of Set 5 | alta floresta
# Processing Record 12 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 5 | manzanares
# Processing Record 14 of Set 5 | vallenar
# Processing Record 15 of Set 5 | pimentel
# Processing Record 16 of Set 5 | dharchula
# Processing Record 17 of Set 5 | piacabucu
# Processing Record 18 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 5 | marystown
# Processing Record 20 of Set 5 | manono
# Processing Record 21 of Set 5 | chanika
# Processing Record 22 of Set 5 | cherskiy
# Processing Record 23 of Set 5 | ambilobe
# Processing Record 24 of Set 5 | saint-avertin
# Processing Record 25 of Set 5 | ballina
# Processing Record 26 of Set 5 | ternate
# Processing Record 27 of Set 5 | sabratah
# Processing Record 28 of Set 5 | upernavik
# Processing Record 29 of Set 5 | raga
# Processing Record 30 of Set 5 | kavaratti
# Processing Record 31 of Set 5 | kudahuvadhoo
# Processing Record 32 of Set 5 | iqaluit
# Processing Record 33 of Set 5 | deputatskiy
# Processing Record 34 of Set 5 | esperance
# Processing Record 35 of Set 5 | koslan
# Processing Record 36 of Set 5 | gwadar
# Processing Record 37 of Set 5 | aloleng
# Processing Record 38 of Set 5 | tabou
# Processing Record 39 of Set 5 | nizhniy tsasuchey
# Processing Record 40 of Set 5 | hollola
# Processing Record 41 of Set 5 | lagoa
# Processing Record 42 of Set 5 | cayenne
# Processing Record 43 of Set 5 | aden
# Processing Record 44 of Set 5 | birao
# Processing Record 45 of Set 5 | adrar
# Processing Record 46 of Set 5 | samarai
# Processing Record 47 of Set 5 | sarkand
# Processing Record 48 of Set 5 | loikaw
# Processing Record 49 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 5 | annau
# Processing Record 1 of Set 6 | bambous virieux
# Processing Record 2 of Set 6 | whitianga
# Processing Record 3 of Set 6 | chokurdakh
# Processing Record 4 of Set 6 | san cristobal
# Processing Record 5 of Set 6 | paraiso
# Processing Record 6 of Set 6 | wanderlandia
# City not found. Skipping...
# Processing Record 7 of Set 6 | shenjiamen
# Processing Record 8 of Set 6 | tatishchevo
# Processing Record 9 of Set 6 | vichuga
# Processing Record 10 of Set 6 | pallasovka
# Processing Record 11 of Set 6 | faya
# Processing Record 12 of Set 6 | sambava
# Processing Record 13 of Set 6 | prince rupert
# Processing Record 14 of Set 6 | vestmannaeyjar
# Processing Record 15 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 6 | gisborne
# Processing Record 17 of Set 6 | egvekinot
# Processing Record 18 of Set 6 | bastia
# Processing Record 19 of Set 6 | flin flon
# Processing Record 20 of Set 6 | tasiilaq
# Processing Record 21 of Set 6 | mount gambier
# Processing Record 22 of Set 6 | novoilinsk
# Processing Record 23 of Set 6 | dikson
# Processing Record 24 of Set 6 | nampula
# Processing Record 25 of Set 6 | waipawa
# Processing Record 26 of Set 6 | lavrentiya
# Processing Record 27 of Set 6 | axim
# Processing Record 28 of Set 6 | hualmay
# Processing Record 29 of Set 6 | sadao
# Processing Record 30 of Set 6 | payson
# Processing Record 31 of Set 6 | linxia
# Processing Record 32 of Set 6 | te anau
# Processing Record 33 of Set 6 | port lincoln
# Processing Record 34 of Set 6 | tutoia
# Processing Record 35 of Set 6 | marshfield
# Processing Record 36 of Set 6 | lujan
# Processing Record 37 of Set 6 | huaihua
# Processing Record 38 of Set 6 | hirara
# Processing Record 39 of Set 6 | korla
# Processing Record 40 of Set 6 | khatanga
# Processing Record 41 of Set 6 | camacha
# Processing Record 42 of Set 6 | noumea
# Processing Record 43 of Set 6 | tuatapere
# Processing Record 44 of Set 6 | pangnirtung
# Processing Record 45 of Set 6 | lantawan
# Processing Record 46 of Set 6 | nagua
# Processing Record 47 of Set 6 | saint-philippe
# Processing Record 48 of Set 6 | kavieng
# Processing Record 49 of Set 6 | evensk
# Processing Record 50 of Set 6 | petropavlovka
# Processing Record 1 of Set 7 | yalta
# Processing Record 2 of Set 7 | erzincan
# Processing Record 3 of Set 7 | cidreira
# Processing Record 4 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 7 | alamosa
# Processing Record 7 of Set 7 | wagar
# Processing Record 8 of Set 7 | ahuimanu
# Processing Record 9 of Set 7 | uruzgan
# Processing Record 10 of Set 7 | agadez
# Processing Record 11 of Set 7 | laguna
# Processing Record 12 of Set 7 | starychi
# Processing Record 13 of Set 7 | saint-louis
# Processing Record 14 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 15 of Set 7 | visnes
# Processing Record 16 of Set 7 | bonthe
# Processing Record 17 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 7 | ulaangom
# Processing Record 19 of Set 7 | biltine
# Processing Record 20 of Set 7 | oga
# Processing Record 21 of Set 7 | tiznit
# Processing Record 22 of Set 7 | lompoc
# Processing Record 23 of Set 7 | namibe
# Processing Record 24 of Set 7 | thinadhoo
# Processing Record 25 of Set 7 | manta
# Processing Record 26 of Set 7 | san patricio
# Processing Record 27 of Set 7 | antofagasta
# Processing Record 28 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 7 | kamenka
# Processing Record 30 of Set 7 | kidal
# Processing Record 31 of Set 7 | waddan
# Processing Record 32 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 33 of Set 7 | diamantino
# Processing Record 34 of Set 7 | yangjiang
# Processing Record 35 of Set 7 | bathsheba
# Processing Record 36 of Set 7 | moerai
# Processing Record 37 of Set 7 | ponte de sor
# Processing Record 38 of Set 7 | coihaique
# Processing Record 39 of Set 7 | cascais
# Processing Record 40 of Set 7 | sharjah
# Processing Record 41 of Set 7 | iskateley
# Processing Record 42 of Set 7 | nanchang
# Processing Record 43 of Set 7 | berberati
# Processing Record 44 of Set 7 | semporna
# Processing Record 45 of Set 7 | plastun
# Processing Record 46 of Set 7 | qaqortoq
# Processing Record 47 of Set 7 | sao filipe
# Processing Record 48 of Set 7 | tagusao
# Processing Record 49 of Set 7 | dingzhou
# Processing Record 50 of Set 7 | muisne
# Processing Record 1 of Set 8 | rumoi
# Processing Record 2 of Set 8 | gumdag
# Processing Record 3 of Set 8 | tazovskiy
# Processing Record 4 of Set 8 | omboue
# Processing Record 5 of Set 8 | zambezi
# Processing Record 6 of Set 8 | coruripe
# Processing Record 7 of Set 8 | los llanos de aridane
# Processing Record 8 of Set 8 | flinders
# Processing Record 9 of Set 8 | russell
# Processing Record 10 of Set 8 | klaksvik
# Processing Record 11 of Set 8 | harper
# Processing Record 12 of Set 8 | vardo
# Processing Record 13 of Set 8 | iracoubo
# Processing Record 14 of Set 8 | souillac
# Processing Record 15 of Set 8 | visby
# Processing Record 16 of Set 8 | trabzon
# Processing Record 17 of Set 8 | ngerengere
# Processing Record 18 of Set 8 | bom jesus
# Processing Record 19 of Set 8 | pangody
# Processing Record 20 of Set 8 | maungaturoto
# Processing Record 21 of Set 8 | udachnyy
# Processing Record 22 of Set 8 | sun prairie
# Processing Record 23 of Set 8 | whitehorse
# Processing Record 24 of Set 8 | vrangel
# Processing Record 25 of Set 8 | sobolevo
# Processing Record 26 of Set 8 | plouzane
# Processing Record 27 of Set 8 | baiao
# Processing Record 28 of Set 8 | belle glade
# Processing Record 29 of Set 8 | kashi
# Processing Record 30 of Set 8 | shu
# Processing Record 31 of Set 8 | tigil
# Processing Record 32 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 8 | zhigansk
# Processing Record 34 of Set 8 | mehamn
# Processing Record 35 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 8 | weatherford
# Processing Record 37 of Set 8 | emba
# Processing Record 38 of Set 8 | barcelona
# Processing Record 39 of Set 8 | mikhaylovka
# Processing Record 40 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 8 | acapetahua
# Processing Record 42 of Set 8 | nanortalik
# Processing Record 43 of Set 8 | dali
# Processing Record 44 of Set 8 | rognan
# Processing Record 45 of Set 8 | kohima
# Processing Record 46 of Set 8 | villa carlos paz
# Processing Record 47 of Set 8 | ukiah
# Processing Record 48 of Set 8 | saint-denis
# Processing Record 49 of Set 8 | khorramshahr
# Processing Record 50 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 9 | baoqing
# Processing Record 2 of Set 9 | chapais
# Processing Record 3 of Set 9 | kahului
# Processing Record 4 of Set 9 | buraydah
# Processing Record 5 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 9 | marzuq
# Processing Record 7 of Set 9 | narsaq
# Processing Record 8 of Set 9 | olinda
# Processing Record 9 of Set 9 | san francisco
# Processing Record 10 of Set 9 | picota
# Processing Record 11 of Set 9 | sibolga
# Processing Record 12 of Set 9 | vetapalem
# Processing Record 13 of Set 9 | port augusta
# Processing Record 14 of Set 9 | muzhi
# Processing Record 15 of Set 9 | peabiru
# Processing Record 16 of Set 9 | san juan bautista
# Processing Record 17 of Set 9 | shahjahanpur
# Processing Record 18 of Set 9 | urumqi
# Processing Record 19 of Set 9 | liku
# Processing Record 20 of Set 9 | tilichiki
# Processing Record 21 of Set 9 | freeport
# Processing Record 22 of Set 9 | les cayes
# Processing Record 23 of Set 9 | cam ranh
# Processing Record 24 of Set 9 | gombong
# Processing Record 25 of Set 9 | vanimo
# Processing Record 26 of Set 9 | ust-maya
# Processing Record 27 of Set 9 | turbat
# Processing Record 28 of Set 9 | pontianak
# Processing Record 29 of Set 9 | monze
# Processing Record 30 of Set 9 | batagay-alyta
# Processing Record 31 of Set 9 | jiexiu
# Processing Record 32 of Set 9 | ginda
# Processing Record 33 of Set 9 | geraldton
# Processing Record 34 of Set 9 | donetsk
# Processing Record 35 of Set 9 | changtu
# Processing Record 36 of Set 9 | plettenberg bay
# Processing Record 37 of Set 9 | zavetnoye
# Processing Record 38 of Set 9 | nouadhibou
# Processing Record 39 of Set 9 | mabaruma
# Processing Record 40 of Set 9 | sanchor
# Processing Record 41 of Set 9 | djibo
# Processing Record 42 of Set 9 | marshalltown
# Processing Record 43 of Set 9 | kushima
# Processing Record 44 of Set 9 | vagur
# Processing Record 45 of Set 9 | mandalgovi
# Processing Record 46 of Set 9 | obo
# Processing Record 47 of Set 9 | katsuura
# Processing Record 48 of Set 9 | rocha
# Processing Record 49 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 9 | menongue
# Processing Record 1 of Set 10 | naziya
# Processing Record 2 of Set 10 | moose factory
# Processing Record 3 of Set 10 | paramonga
# Processing Record 4 of Set 10 | yar-sale
# Processing Record 5 of Set 10 | leningradskiy
# Processing Record 6 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 10 | paracuru
# Processing Record 8 of Set 10 | dhidhdhoo
# Processing Record 9 of Set 10 | asha
# Processing Record 10 of Set 10 | taunsa
# Processing Record 11 of Set 10 | nanakuli
# Processing Record 12 of Set 10 | abatskoye
# Processing Record 13 of Set 10 | worland
# Processing Record 14 of Set 10 | dalvik
# Processing Record 15 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 10 | nisia floresta
# Processing Record 17 of Set 10 | springdale
# Processing Record 18 of Set 10 | san pedro
# Processing Record 19 of Set 10 | ponta delgada
# Processing Record 20 of Set 10 | sal rei
# Processing Record 21 of Set 10 | finschhafen
# Processing Record 22 of Set 10 | eskisehir
# Processing Record 23 of Set 10 | placido de castro
# Processing Record 24 of Set 10 | mohelnice
# Processing Record 25 of Set 10 | yaan
# Processing Record 26 of Set 10 | selfoss
# Processing Record 27 of Set 10 | horta
# Processing Record 28 of Set 10 | rach gia
# Processing Record 29 of Set 10 | manaquiri
# Processing Record 30 of Set 10 | abiy adi
# City not found. Skipping...
# Processing Record 31 of Set 10 | padang
# Processing Record 32 of Set 10 | bilibino
# Processing Record 33 of Set 10 | airai
# Processing Record 34 of Set 10 | mpika
# Processing Record 35 of Set 10 | lisala
# Processing Record 36 of Set 10 | rafaela
# Processing Record 37 of Set 10 | debre tabor
# Processing Record 38 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 10 | panzhihua
# Processing Record 40 of Set 10 | sumenep
# Processing Record 41 of Set 10 | mnogovershinnyy
# Processing Record 42 of Set 10 | coquimbo
# Processing Record 43 of Set 10 | penjamo
# Processing Record 44 of Set 10 | laurens
# Processing Record 45 of Set 10 | high level
# Processing Record 46 of Set 10 | asau
# Processing Record 47 of Set 10 | havoysund
# Processing Record 48 of Set 10 | murindo
# Processing Record 49 of Set 10 | mingshui
# Processing Record 50 of Set 10 | staryy nadym
# Processing Record 1 of Set 11 | kenai
# Processing Record 2 of Set 11 | grand gaube
# Processing Record 3 of Set 11 | chernyshevskiy
# Processing Record 4 of Set 11 | lac du bonnet
# Processing Record 5 of Set 11 | cortes
# Processing Record 6 of Set 11 | yingzhong
# City not found. Skipping...
# Processing Record 7 of Set 11 | aykino
# Processing Record 8 of Set 11 | juba
# Processing Record 9 of Set 11 | guicheng
# City not found. Skipping...
# Processing Record 10 of Set 11 | basoko
# Processing Record 11 of Set 11 | zabid
# Processing Record 12 of Set 11 | aykhal
# Processing Record 13 of Set 11 | krylovskaya
# Processing Record 14 of Set 11 | thunder bay
# Processing Record 15 of Set 11 | buenos aires
# Processing Record 16 of Set 11 | san lorenzo
# Processing Record 17 of Set 11 | gambela
# Processing Record 18 of Set 11 | antalaha
# Processing Record 19 of Set 11 | quatre cocos
# Processing Record 20 of Set 11 | tambacounda
# Processing Record 21 of Set 11 | kungurtug
# Processing Record 22 of Set 11 | hun
# Processing Record 23 of Set 11 | tiarei
# Processing Record 24 of Set 11 | puerto del rosario
# Processing Record 25 of Set 11 | morondava
# Processing Record 26 of Set 11 | sakaiminato
# Processing Record 27 of Set 11 | ormara
# Processing Record 28 of Set 11 | cervo
# Processing Record 29 of Set 11 | kijang
# Processing Record 30 of Set 11 | wonthaggi
# Processing Record 31 of Set 11 | cockburn town
# Processing Record 32 of Set 11 | japura
# Processing Record 33 of Set 11 | tubbergen
# Processing Record 34 of Set 11 | husavik
# Processing Record 35 of Set 11 | nuevo progreso
# Processing Record 36 of Set 11 | kurilsk
# Processing Record 37 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 38 of Set 11 | shenzhen
# Processing Record 39 of Set 11 | vada
# Processing Record 40 of Set 11 | gavle
# Processing Record 41 of Set 11 | aktash
# Processing Record 42 of Set 11 | asosa
# Processing Record 43 of Set 11 | meulaboh
# Processing Record 44 of Set 11 | monrovia
# Processing Record 45 of Set 11 | porto nacional
# Processing Record 46 of Set 11 | muros
# Processing Record 47 of Set 11 | okha
# Processing Record 48 of Set 11 | irbeyskoye
# Processing Record 49 of Set 11 | linhares
# Processing Record 50 of Set 11 | ilebo
# Processing Record 1 of Set 12 | vieques
# Processing Record 2 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 12 | taltal
# Processing Record 4 of Set 12 | fairbanks
# Processing Record 5 of Set 12 | altay
# Processing Record 6 of Set 12 | baykit
# Processing Record 7 of Set 12 | elizabeth city
# Processing Record 8 of Set 12 | kiama
# Processing Record 9 of Set 12 | srednekolymsk
# Processing Record 10 of Set 12 | bosaso
# Processing Record 11 of Set 12 | kayankulam
# Processing Record 12 of Set 12 | tres arroyos
# Processing Record 13 of Set 12 | marsabit
# Processing Record 14 of Set 12 | krasnooktyabrskiy
# Processing Record 15 of Set 12 | yarada
# Processing Record 16 of Set 12 | birjand
# Processing Record 17 of Set 12 | ejea de los caballeros
# Processing Record 18 of Set 12 | neiafu
# Processing Record 19 of Set 12 | markkleeberg
# Processing Record 20 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 12 | kirensk
# Processing Record 22 of Set 12 | krasnoarmeysk
# Processing Record 23 of Set 12 | anahuac
# Processing Record 24 of Set 12 | gyongyostarjan
# Processing Record 25 of Set 12 | severo-kurilsk
# Processing Record 26 of Set 12 | praia
# Processing Record 27 of Set 12 | parrita
# Processing Record 28 of Set 12 | oelde
# Processing Record 29 of Set 12 | shimoda
# Processing Record 30 of Set 12 | uyuni
# Processing Record 31 of Set 12 | maloy
# Processing Record 32 of Set 12 | oranjestad
# Processing Record 33 of Set 12 | senneterre
# Processing Record 34 of Set 12 | belem de sao francisco
# Processing Record 35 of Set 12 | ostuni
# Processing Record 36 of Set 12 | pindwara
# Processing Record 37 of Set 12 | belaya gora
# Processing Record 38 of Set 12 | vila velha
# Processing Record 39 of Set 12 | mangaratiba
# Processing Record 40 of Set 12 | kangaatsiaq
# Processing Record 41 of Set 12 | bonavista
# Processing Record 42 of Set 12 | belmonte
# Processing Record 43 of Set 12 | impfondo
# Processing Record 44 of Set 12 | alakurtti
# Processing Record 45 of Set 12 | sumbe
# Processing Record 46 of Set 12 | tawzar
# City not found. Skipping...
# Processing Record 47 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 12 | guerrero negro
# Processing Record 49 of Set 12 | sidi ali
# Processing Record 50 of Set 12 | kawalu
# Processing Record 1 of Set 13 | tecoanapa
# Processing Record 2 of Set 13 | chhatapur
# Processing Record 3 of Set 13 | pyapon
# Processing Record 4 of Set 13 | foeni
# Processing Record 5 of Set 13 | rawlins
# Processing Record 6 of Set 13 | dingle
# Processing Record 7 of Set 13 | bowen
# Processing Record 8 of Set 13 | grand-santi
# Processing Record 9 of Set 13 | tual
# Processing Record 10 of Set 13 | bandarbeyla
# Processing Record 11 of Set 13 | ostrovnoy
# Processing Record 12 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 13 | abyek
# Processing Record 14 of Set 13 | fortuna
# Processing Record 15 of Set 13 | scarborough
# Processing Record 16 of Set 13 | zaysan
# Processing Record 17 of Set 13 | mandurah
# Processing Record 18 of Set 13 | tanete
# Processing Record 19 of Set 13 | mayumba
# Processing Record 20 of Set 13 | guarapuava
# Processing Record 21 of Set 13 | libertador general san martin
# Processing Record 22 of Set 13 | itarema
# Processing Record 23 of Set 13 | acarau
# Processing Record 24 of Set 13 | kisesa
# Processing Record 25 of Set 13 | arlit
# Processing Record 26 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 13 | jizan
# Processing Record 28 of Set 13 | oneonta
# Processing Record 29 of Set 13 | sena madureira
# Processing Record 30 of Set 13 | brae
# Processing Record 31 of Set 13 | tamworth
# Processing Record 32 of Set 13 | alugan
# Processing Record 33 of Set 13 | epiniana
# Processing Record 34 of Set 13 | awjilah
# Processing Record 35 of Set 13 | shitanjing
# Processing Record 36 of Set 13 | bulgan
# Processing Record 37 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 13 | wellington
# Processing Record 39 of Set 13 | tucupita
# Processing Record 40 of Set 13 | pombia
# Processing Record 41 of Set 13 | yulara
# Processing Record 42 of Set 13 | grand forks
# Processing Record 43 of Set 13 | kanigoro
# Processing Record 44 of Set 13 | oistins
# Processing Record 45 of Set 13 | borogontsy
# Processing Record 46 of Set 13 | kalabo
# Processing Record 47 of Set 13 | srivardhan
# Processing Record 48 of Set 13 | igarka
# Processing Record 49 of Set 13 | la rioja
# Processing Record 50 of Set 13 | berlevag
# Processing Record 1 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 14 | zhezkazgan
# Processing Record 3 of Set 14 | assomada
# Processing Record 4 of Set 14 | keshan
# City not found. Skipping...
# Processing Record 5 of Set 14 | murray bridge
# Processing Record 6 of Set 14 | bargur
# Processing Record 7 of Set 14 | novovelichkovskaya
# Processing Record 8 of Set 14 | sechura
# Processing Record 9 of Set 14 | awbari
# Processing Record 10 of Set 14 | linqiong
# Processing Record 11 of Set 14 | nyimba
# Processing Record 12 of Set 14 | juneau
# Processing Record 13 of Set 14 | asilah
# Processing Record 14 of Set 14 | mackay
# Processing Record 15 of Set 14 | inhambane
# Processing Record 16 of Set 14 | san gavino monreale
# Processing Record 17 of Set 14 | tamandare
# Processing Record 18 of Set 14 | henties bay
# Processing Record 19 of Set 14 | ust-karsk
# Processing Record 20 of Set 14 | serrana
# Processing Record 21 of Set 14 | taksimo
# Processing Record 22 of Set 14 | hamilton
# Processing Record 23 of Set 14 | riyadh
# Processing Record 24 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 14 | livingstone
# Processing Record 26 of Set 14 | miri
# Processing Record 27 of Set 14 | santa cruz
# Processing Record 28 of Set 14 | bacong
# Processing Record 29 of Set 14 | ondjiva
# Processing Record 30 of Set 14 | severo-yeniseyskiy
# Processing Record 31 of Set 14 | tautira
# Processing Record 32 of Set 14 | myitkyina
# Processing Record 33 of Set 14 | bubaque
# Processing Record 34 of Set 14 | huangcun
# Processing Record 35 of Set 14 | tukan
# Processing Record 36 of Set 14 | alyangula
# Processing Record 37 of Set 14 | charlestown
# Processing Record 38 of Set 14 | benguela
# Processing Record 39 of Set 14 | lewiston
# Processing Record 40 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 14 | marsh harbour
# Processing Record 42 of Set 14 | severodvinsk
# Processing Record 43 of Set 14 | laguna de duero
# Processing Record 44 of Set 14 | pacific grove
# Processing Record 45 of Set 14 | bira
# Processing Record 46 of Set 14 | paamiut
# Processing Record 47 of Set 14 | mathathane
# Processing Record 48 of Set 14 | mandera
# Processing Record 49 of Set 14 | isangel
# Processing Record 50 of Set 14 | avera
# Processing Record 1 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 15 | college
# Processing Record 3 of Set 15 | freetown
# Processing Record 4 of Set 15 | cape coast
# Processing Record 5 of Set 15 | okhotsk
# Processing Record 6 of Set 15 | lerwick
# Processing Record 7 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 15 | higuey
# City not found. Skipping...
# Processing Record 9 of Set 15 | maryborough
# Processing Record 10 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 11 of Set 15 | kuytun
# Processing Record 12 of Set 15 | gari
# Processing Record 13 of Set 15 | perth
# Processing Record 14 of Set 15 | beringovskiy
# Processing Record 15 of Set 15 | yeppoon
# Processing Record 16 of Set 15 | montrose
# Processing Record 17 of Set 15 | concordia
# Processing Record 18 of Set 15 | aripuana
# Processing Record 19 of Set 15 | patan
# Processing Record 20 of Set 15 | torit
# Processing Record 21 of Set 15 | nhulunbuy
# Processing Record 22 of Set 15 | mende
# Processing Record 23 of Set 15 | wakema
# Processing Record 24 of Set 15 | tolbazy
# Processing Record 25 of Set 15 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 26 of Set 15 | port hedland
# Processing Record 27 of Set 15 | bani walid
# Processing Record 28 of Set 15 | hasaki
# Processing Record 29 of Set 15 | cartagena
# Processing Record 30 of Set 15 | martapura
# Processing Record 31 of Set 15 | bereda
# Processing Record 32 of Set 15 | auki
# Processing Record 33 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 34 of Set 15 | rolla
# Processing Record 35 of Set 15 | anloga
# Processing Record 36 of Set 15 | saurimo
# Processing Record 37 of Set 15 | roald
# Processing Record 38 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 39 of Set 15 | moengo
# Processing Record 40 of Set 15 | solano
# Processing Record 41 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 15 | wewak
# Processing Record 43 of Set 15 | tromso
# Processing Record 44 of Set 15 | puerto escondido
# Processing Record 45 of Set 15 | yatou
# Processing Record 46 of Set 15 | la ronge
# Processing Record 47 of Set 15 | manokwari
# Processing Record 48 of Set 15 | kirgiz-miyaki
# Processing Record 49 of Set 15 | siddapur
# Processing Record 50 of Set 15 | lasa
# Processing Record 1 of Set 16 | inuvik
# Processing Record 2 of Set 16 | solnechnyy
# Processing Record 3 of Set 16 | ambunti
# Processing Record 4 of Set 16 | vievis
# Processing Record 5 of Set 16 | colares
# Processing Record 6 of Set 16 | lumeje
# Processing Record 7 of Set 16 | barmer
# Processing Record 8 of Set 16 | coyuca
# City not found. Skipping...
# Processing Record 9 of Set 16 | bang saphan
# Processing Record 10 of Set 16 | olonets
# Processing Record 11 of Set 16 | mlonggo
# Processing Record 12 of Set 16 | dharampuri
# Processing Record 13 of Set 16 | great falls
# Processing Record 14 of Set 16 | sinnamary
# Processing Record 15 of Set 16 | nome
# Processing Record 16 of Set 16 | kakching
# Processing Record 17 of Set 16 | luwuk
# Processing Record 18 of Set 16 | chegdomyn
# Processing Record 19 of Set 16 | keuruu
# Processing Record 20 of Set 16 | buariki
# City not found. Skipping...
# Processing Record 21 of Set 16 | kingaroy
# Processing Record 22 of Set 16 | kargasok
# Processing Record 23 of Set 16 | sangueya
# Processing Record 24 of Set 16 | rubtsovsk
# Processing Record 25 of Set 16 | ruwi
# Processing Record 26 of Set 16 | meshchovsk
# Processing Record 27 of Set 16 | gat
# Processing Record 28 of Set 16 | lysyanka
# Processing Record 29 of Set 16 | massakory
# Processing Record 30 of Set 16 | north platte
# Processing Record 31 of Set 16 | brokopondo
# Processing Record 32 of Set 16 | terrak
# Processing Record 33 of Set 16 | alice springs
# Processing Record 34 of Set 16 | cururupu
# Processing Record 35 of Set 16 | izumo
# Processing Record 36 of Set 16 | do rud
# City not found. Skipping...
# Processing Record 37 of Set 16 | omsukchan
# Processing Record 38 of Set 16 | doha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Broome  42.2506  -75.8330     17.62        69          40
# 1           Kankon  15.0167   74.0167     73.20        66           6
# 2          Ushuaia -54.8000  -68.3000     38.86        81          40
# 3         Carauari  -4.8828  -66.8958     73.27        99         100
# 4        Cape Town -33.9258   18.4232     71.11        79          20
# ..             ...      ...       ...       ...       ...         ...
# 722  Alice Springs -23.7000  133.8833     87.35        27           0
# 723       Cururupu  -1.8283  -44.8683     74.30        96          98
# 724          Izumo  35.3667  132.7667     45.68        65          22
# 725      Omsukchan  62.5333  155.8000    -17.01        96          50
# 726           Doha  25.2867   51.5333     62.58        63           0
#
#      Wind Speed Country Current Description
# 0         10.36      US    scattered clouds
# 1          4.50      IN           clear sky
# 2         26.46      AR    scattered clouds
# 3          1.39      BR     overcast clouds
# 4         18.41      ZA          few clouds
# ..          ...     ...                 ...
# 722        8.05      AU           clear sky
# 723        3.18      BR          light rain
# 724       15.17      JP          few clouds
# 725        4.79      RU    scattered clouds
# 726       10.36      QA           clear sky
#
# [727 rows x 9 columns]

# %%
# Reorder columns.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Broome      US  42.2506  -75.8330     17.62        69          40
# 1           Kankon      IN  15.0167   74.0167     73.20        66           6
# 2          Ushuaia      AR -54.8000  -68.3000     38.86        81          40
# 3         Carauari      BR  -4.8828  -66.8958     73.27        99         100
# 4        Cape Town      ZA -33.9258   18.4232     71.11        79          20
# ..             ...     ...      ...       ...       ...       ...         ...
# 722  Alice Springs      AU -23.7000  133.8833     87.35        27           0
# 723       Cururupu      BR  -1.8283  -44.8683     74.30        96          98
# 724          Izumo      JP  35.3667  132.7667     45.68        65          22
# 725      Omsukchan      RU  62.5333  155.8000    -17.01        96          50
# 726           Doha      QA  25.2867   51.5333     62.58        63           0
#
#      Wind Speed Current Description
# 0         10.36    scattered clouds
# 1          4.50           clear sky
# 2         26.46    scattered clouds
# 3          1.39     overcast clouds
# 4         18.41          few clouds
# ..          ...                 ...
# 722        8.05           clear sky
# 723        3.18          light rain
# 724       15.17          few clouds
# 725        4.79    scattered clouds
# 726       10.36           clear sky
#
# [727 rows x 9 columns]

# %%
# 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
#Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
